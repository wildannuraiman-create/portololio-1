# %%
print('Hello world')
# Out:
# Hello world

# %%
print(7+3)
# Out:
# 10

# %%
print('Hallo temen2 DS batch 37 dibimbing')
# Out:
# Hallo temen2 DS batch 37 dibimbing

# %%
print('halo ka kurnia')
